# %% [markdown]
# <a href="https://colab.research.google.com/github/Jennymmmmm/lis5693/blob/main/Lab_2_Jenny_Min.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %% [markdown]
# **TASK 1: Load and read your transcript.txt file from lab-1 from GitHub repo directly**

# %%
import requests

url = "https://raw.githubusercontent.com/Jennymmmmm/lis5693/refs/heads/main/lab-1/transcript_Jenny%20Min"
response = requests.get(url)
response.raise_for_status() # Raise an exception for HTTP errors
text = response.text

# %% [markdown]
# **TASK 2: How many characters are in your transcript? Print the first 100 characters**

# %%
print("Number of characters:", len(text)) # print number of characters

print(text[:100])   # print first 100 characters
# Out:
# Number of characters: 4270
# Transcriber: Ivana Korom
# Reviewer:
# [Baby cooing]
# What if I was to tell you
# that a game of peekaboo

# %% [markdown]
# **TASK 3: Perform sentence segmentation using the blank pipeline**

# %%
nlp = spacy.blank("en")
nlp.add_pipe("sentencizer")

doc = nlp(text)

sentences = list(doc.sents)

print("Number of sentences:", len(sentences))

print("\nFirst 3 sentences:")
for sent in sentences[:3]:
    print(sent)
# Out:
# Number of sentences: 80
#
# First 3 sentences:
# Transcriber: Ivana Korom
# Reviewer:
# [Baby cooing]
# What if I was to tell you
# that a game of peekaboo
# could change the world?
#
# Sounds impossible, right?
#
# Well, I’m here today to prove it’s not.

# %% [markdown]
# Q: How many sentences are in your transcript? A: 80 sentences
# Q: Print the first 3 sentences A: Transcriber: Ivana Korom
# Reviewer:
# [Baby cooing]
# What if I was to tell you
# that a game of peekaboo
# could change the world?
#
# Sounds impossible, right?
#
# Well, I’m here today to prove it’s not.

# %% [markdown]
# **TASK 4: Perform Word Count and Token Analysis**

# %%
words = [token.text.lower() for token in doc if token.is_alpha]

print("Total words:", len(words))
print("Unique words:", len(set(words)))
# Out:
# Total words: 765
# Unique words: 326

# %% [markdown]
# **TASK 5: Find Most Frequent Words**

# %%
from collections import Counter

word_freq = Counter(words)

print("Top 10 most frequent words:")
for word, count in word_freq.most_common(10):
    print(word, count)
# Out:
# Top 10 most frequent words:
# and 38
# the 26
# to 23
# our 16
# a 14
# ari 14
# it 13
# that 10
# he 10
# is 9

# %% [markdown]
# The most frequent word from the transcript is 'and'. This is a common result because ‘and’ is a function word, and the presenter in the video—a young child—tends to use it frequently for linguistic and developmental reasons.

# %% [markdown]
# **TASK 6: Run full spaCy pipeline**

# %%
nlp2 = spacy.load("en_core_web_sm")

doc2 = nlp2(text)

print("Named Entities:")
for ent in doc2.ents:
    print(ent.text, ent.label_)
# Out:
# Named Entities:
# Ivana Korom
# Reviewer PERSON
# today DATE
# seven CARDINAL
# Ari PERSON
# Amarjot GPE
# Ari PERSON
# today DATE
# the first five years DATE
# Ari PERSON
# Ari PERSON
# the first year DATE
# almost 90 percent PERCENT
# our early years DATE
# up to one million CARDINAL
# five CARDINAL
# One CARDINAL
# two CARDINAL
# three CARDINAL
# four CARDINAL
# five CARDINAL
# Amarjot GPE
# Ari PERSON
# Molly Wright PERSON
# Amarjot GPE
# Ari PERSON
# Amarjot GPE
# one day DATE
# seven-year-old DATE
# ’s GPE
# Amarjot GPE
# ’s Ari PERSON
# Ari PERSON
# last 30 seconds TIME
# the first five years DATE
# Serve PERSON
# Amarjot GPE
# Ari PERSON

# %% [markdown]
# Q: How many named entities were found? A: 38
#
# Q: What types of entities appear? A: PERSON, DATE, CARDINAL, GPE, TIME, PERCENT

# %% [markdown]
# **TASK 7: Use PhraseMatcher**

# %%
from spacy.matcher import PhraseMatcher

matcher = PhraseMatcher(nlp2.vocab, attr="LOWER")

phrases = ["play", "brain", "baby"]

patterns = [nlp2(p) for p in phrases]

matcher.add("TECH_TERMS", patterns)

matches = matcher(doc2)

print("Matches found:")
for match_id, start, end in matches:
    print(doc2[start:end])
    print("Sentence:", doc2[start].sent)
# Out:
# Matches found:
# Baby
# Sentence: [Baby cooing]
# What if I was to tell you
# that a game of peekaboo
# could change the world?
# Sounds impossible, right?
#
# baby
# Sentence: The blue bag is a rough size and weight
# of a healthy baby’s brain at birth.
#
# brain
# Sentence: The blue bag is a rough size and weight
# of a healthy baby’s brain at birth.
#
# baby
# Sentence: The red one is a baby’s brain
# after the first year.
#
# brain
# Sentence: The red one is a baby’s brain
# after the first year.
#
# brain
# Sentence: And by my age, it's almost 90 percent
# the volume of an adult brain.
#
# play
# Sentence: That’s just a grown-up way of saying
# connect, talk and play with us.
#
# play
# Sentence: Amarjot: Peekaboo!
# MW: Each time you talk to us,
# play with us, make us laugh,
# it not only builds and strengthens
# our relationships and mental health,
# it actually teaches us
# some of the most important life skills,
# from making friends to taking the test,
# to getting a job,
# ...

# %% [markdown]
# **TASK 8: At the end of your Colab notebook, create a new text cell and write a brief reflection for this assignment in a few sentences addressing the following**

# %% [markdown]
# Following the detailed instructions provided in the Google Colab file made the entire process smooth and efficient. Although this was my first time working through this type of coding task, it helped me understand the concepts in each section and allowed me to visualize how these methods could be applied in my future research. The reason I chose this video was that it presented a young child sharing her own perspective and emphasizing the importance of play from a child’s point of view. However, one challenge I noticed during this assignment was that the analysis might have been more insightful if I had selected a video with denser content and more informational depth, which could have produced more interesting results.
